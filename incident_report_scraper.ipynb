# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
from typing import Dict, List
import pyprind
from math import cos, pi, floor
from datetime import datetime

# %%
def parse_challenge(page):
    """
    Parse a challenge given by mmi and mavat's web servers, forcing us to solve
    some math stuff and send the result as a header to actually get the page.
    This logic is pretty much copied from https://github.com/R3dy/jigsaw-rails/blob/master/lib/breakbot.rb
    """
    top = page.split('<script>')[1].split('\n')
    challenge = top[1].split(';')[0].split('=')[1]
    challenge_id = top[2].split(';')[0].split('=')[1]
    return {'challenge': challenge, 'challenge_id': challenge_id, 'challenge_result': get_challenge_answer(challenge)}

def telegram_bot_sendtext(bot_message: str) -> None:
    """
    Send telegram msg for my bot
    """
    bot_token = '1172952527:AAGoM74Rx25DPBpmQhEwacs_AQ9GWI8Oybk'
    chat_id = "839266998"
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + chat_id + '&parse_mode=Markdown&text=' + bot_message
    requests.get(send_text)

def get_challenge_answer(challenge):
    """
    Solve the math part of the challenge and get the result
    """
    arr = list(challenge)
    last_digit = int(arr[-1])
    arr.sort()
    min_digit = int(arr[0])
    subvar1 = (2 * int(arr[2])) + int(arr[1])
    subvar2 = str(2 * int(arr[2])) + arr[1]
    power = ((int(arr[0]) * 1) + 2) ** int(arr[1])
    x = (int(challenge) * 3 + subvar1)
    y = cos(pi * subvar1)
    answer = x * y
    answer -= power
    answer += (min_digit - last_digit)
    answer = str(int(floor(answer))) + subvar2
    return answer

def make_hkjc_request(url: str) -> str:
    headers = {'User-agent': 'Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.1) Gecko/2008071615 Fedora/3.0.1-1.fc9 Firefox/3.0.1'}
    with requests.Session() as s:
        r = s.get(url, headers = headers)
        if 'X-AA-Challenge' in r.text:
            challenge = parse_challenge(r.text)
            cookies = s.get(url, headers={
                'X-AA-Challenge': challenge['challenge'],
                'X-AA-Challenge-ID': challenge['challenge_id'],
                'X-AA-Challenge-Result': challenge['challenge_result']
            }).cookies  
        else:
            cookies = r.cookies

        r = s.post(url, cookies = cookies)

    return r.text

def evaluate_course(title):
    clean_title = title.replace(" ","").lower()
    if "shatin" in clean_title:
        return "ST"
    
    elif "happyvalley" in clean_title:
        return "HV"
    
    else:
        return None


def scrape_prize_pool(date) -> pd.DataFrame:
    df = pd.DataFrame()
    
    html_list = []
    # first race
    url = f"https://racing.hkjc.com/racing/information/english/Racing/LocalResults.aspx?RaceDate={date}"
    first_race = make_hkjc_request(url)
    soup = BeautifulSoup(first_race, "lxml")
    html_list.append(soup)

    # extract info
    num_of_races = len(soup.find("table", attrs = {"class": re.compile("f_fs12.+racecard$")}).find_all("a"))
    course = evaluate_course(str(soup.find("span", attrs = {"class": "f_fl f_fs13"})))
    #overhead_text = soup.find("tr", attrs = {"class": re.compile("bg_blue.+font_wb$")}).get_text()
    #first_race_no = re.search("\((\d+)\)", overhead_text).group(1)

    # extract info for all other races and append to html_list
    for i in range(2, num_of_races):
        url = f"https://racing.hkjc.com/racing/information/english/Racing/LocalResults.aspx?RaceDate={date}&Racecourse={course}&RaceNo={str(i)}"
        race_info = make_hkjc_request(url)
        soup = BeautifulSoup(race_info, "lxml")
        html_list.append(soup)

    # get prize pool and race_number
    for soup in html_list:
        try:
            df_temp = pd.DataFrame(columns = ["race_no", "date", "incident_report"])
            overhead_text = soup.find("tr", attrs = {"class": re.compile("bg_blue.+font_wb$")}).get_text()
            race_no = re.search("\((\d+)\)", overhead_text).group(1)
            df_temp["race_no"] = race_no
            df_temp["date"] = date
            try:
                df_temp["incident_report"] = soup.find("div", attrs = {"class": "race_incident_report"}).get_text()
            except AttributeError:
                df_temp["incident_report"] = ""
            
            for col in df_temp.columns:
                df_temp[col] = [str(x) for x in df_temp[col]]

            df = df.append(df_temp)
            
        except ValueError:
            pass

    return df

def remove_scraped_date(date_list: list) -> list:
    """
    read status.txt and remove those already been successfully scraped
    return a filtered horse_id_list for future loops
    """
    with open("status_incident_report.txt","r",encoding = 'utf-8') as txt:
        status = txt.readlines()
        status = [x.replace('\n','') for x in status]
    date_list = [x for x in date_list if x not in status]
    return date_list

def update_status(date: str) -> None:
    with open("status_incident_report.txt","a+",encoding = 'utf-8') as txt:
        txt.write(date+"\n")

# %%
if __name__ == "__main__":
    # fetch date list
    telegram_bot_sendtext(f"Prize pool scraper program started at {str(datetime.now())}.")
    error_list = []
    date_list = list(pd.read_pickle("1_horse_id_data.pkl")["date"])
    date_list = remove_scraped_date(date_list)

    print(f"Total {str(len(date_list))} race days.")
    bar = pyprind.ProgBar(len(date_list))
    
    for date in date_list:
        try:
            status_int = 0
            df = scrape_prize_pool(date)            

            # write to hd5 -> hd5 defaults to append mode
            df.to_hdf(r"data_20200822\incident_report.h5", key = "incident_report", append = True, format = "table")
            
            # report status to telegram
            if status_int % 500 == 0 and status_int > 0:
                telegram_bot_sendtext(f"Incident report scraper - completed {str(status_int)} out of {str(len(date_list))} at {str(datetime.now())} with {len(error_list)} errors.")

            bar.update()
            update_status(date)
            status_int += 1

        except Exception as e:
            status_int +=1
            print(f"{date}: {str(e)}")
            error_list.append((date, str(e)))
            bar.update()
# Out:
# Total 1611 race days.
# 2002/09/01: 'NoneType' object has no attribute 'get_text'
# 0% [###                           ] 100% | ETA: 14:27:31
# 2008/03/30: 'NoneType' object has no attribute 'get_text'
# 2008/12/28: 'NoneType' object has no attribute 'get_text'
# 0% [####                          ] 100% | ETA: 17:09:21
# 2009/05/17: 'NoneType' object has no attribute 'get_text'
# 2009/10/04: 'NoneType' object has no attribute 'get_text'
# 2010/02/07: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/02/07&Racecourse=ST&RaceNo=2 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [WinError 10053] An established connection was aborted by the software in your host machine'))
# 2010/02/21: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/02/21 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/02/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/02/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/03/14: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/03/14 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/03/21: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/03/21 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/03/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/03/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/04/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/04/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/04/18: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/04/18 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/04/25: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/04/25 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552700>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/05/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/05/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/05/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/05/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/05/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/05/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/06/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/06/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/06/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/06/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/06/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/06/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/07/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/07/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/07/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/07/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/07/11: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/07/11 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835525B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/09/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/09/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/09/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/09/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/09/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/09/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/09/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/09/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/10/10: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/10/10 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 0% [#####                         ] 100% | ETA: 15:22:50
# 2010/10/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/10/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/10/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/10/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/10/31: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/10/31 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/11/14: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/11/14 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/11/21: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/11/21 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835525E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/11/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/11/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/12/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/12/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/12/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/12/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2010/12/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2010/12/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/01/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/01/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/01/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/01/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/01/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/01/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/01/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/01/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/02/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/02/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/02/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/02/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/03/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/03/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/03/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/03/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/03/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/03/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/04/03: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/04/03 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/04/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/04/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/05/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/05/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/05/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/05/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/05/29: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/05/29 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/06/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/06/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/06/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/06/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/06/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/06/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/07/10: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/07/10 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835525B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/09/11: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/09/11 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/09/18: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/09/18 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/09/25: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/09/25 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552880>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/10/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/10/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/10/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/10/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/10/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/10/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/10/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/10/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/10/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/10/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835525B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/11/13: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/11/13 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A30>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/11/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/11/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/11/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/11/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552880>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/12/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/12/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2011/12/11: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2011/12/11 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/01/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/01/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/01/08: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/01/08 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/01/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/01/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/01/29: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/01/29 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/02/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/02/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/02/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/02/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552880>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/02/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/02/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552580>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/03/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/03/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835527C0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/03/18: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/03/18 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/03/25: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/03/25 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/04/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/04/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552A60>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/04/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/04/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552970>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/04/29: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/04/29 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/05/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/05/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552880>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 0% [######                        ] 100% | ETA: 12:17:40
# 2012/05/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/05/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835529D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/06/03: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/06/03 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835525B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/06/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/06/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/06/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/06/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835528E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/07/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/07/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835526A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/07/08: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/07/08 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552760>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/07/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/07/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552940>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/09/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/09/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835522E0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/09/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/09/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/10/14: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/10/14 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/10/21: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/10/21 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835300A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/10/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/10/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835300D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/11/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/11/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983530100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/11/18: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/11/18 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/11/25: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/11/25 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/12/02: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/12/02 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/12/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/12/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2012/12/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2012/12/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/01/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/01/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/01/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/01/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/01/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/01/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/02/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/02/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/02/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/02/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/03/10: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/03/10 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/03/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/03/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983562F70>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/03/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/03/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/04/07: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/04/07 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835620D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/04/14: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/04/14 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/04/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/04/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/05/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/05/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/05/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/05/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/06/02: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/06/02 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835630D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/06/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/06/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835520D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/06/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/06/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983552100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/07/04: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/07/04 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835620D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/07/07: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/07/07 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/09/08: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/09/08 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835620D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/09/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/09/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/10/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/10/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/10/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/10/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/10/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/10/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/11/03: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/11/03 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/11/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/11/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/11/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/11/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/12/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/12/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/12/08: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/12/08 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/12/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/12/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/12/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/12/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2013/12/29: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2013/12/29 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/01/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/01/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/01/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/01/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/01/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/01/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835610D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/02/02: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/02/02 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/02/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/02/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B100>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/02/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/02/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/03/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/03/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/03/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/03/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/03/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/03/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298356B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/03/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/03/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835390D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2014/04/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2014/04/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000002298353B0D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 0% [#######                       ] 100% | ETA: 54:17:56
# ...
# 2007/04/18: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/04/18 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/04/25: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/04/25 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/05/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/05/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/05/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/05/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/05/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/05/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B9E130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/05/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/05/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B9E130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/06/06: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/06/06 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/06/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/06/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/06/13: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/06/13 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/06/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/06/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/09/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/09/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/09/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/09/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/09/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/09/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B90130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/09/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/09/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/10/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/10/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/10/24: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/10/24 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/10/31: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/10/31 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B60190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/11/03: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/11/03 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/11/14: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/11/14 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/11/17: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/11/17 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/11/21: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/11/21 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/11/28: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/11/28 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/12/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/12/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/12/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/12/15: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/15 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2007/12/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 0% [###################           ] 100% | ETA: 09:33:28
# 2007/12/26: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2007/12/26 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B6A130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/01/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/01/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/01/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/01/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/01/16: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/01/16 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/01/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/01/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B64130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/01/30: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/01/30 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B64130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/02/02: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/02/02 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B64130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/02/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/02/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B8E130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/02/13: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/02/13 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B8E160>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/02/20: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/02/20 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B8E160>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/02/27: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/02/27 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/03/01: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/03/01 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/03/05: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/03/05 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B8E160>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/03/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/03/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022989B8E160>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/03/19: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/03/19 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/04/02: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/04/02 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/04/09: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/04/09 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/04/12: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/04/12 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000022983629130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# 2008/04/23: HTTPSConnectionPool(host='racing.hkjc.com', port=443): Max retries exceeded with url: /racing/information/english/Racing/LocalResults.aspx?RaceDate=2008/04/23 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000229835F6130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
